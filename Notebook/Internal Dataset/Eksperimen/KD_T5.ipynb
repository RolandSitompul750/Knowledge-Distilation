JPG
#   inflating: /content/drive/MyDrive/Tomato Dataset_KD_T5_A0.3_test2/tomato/val/Tomato___healthy/Tomato___healthy_original_1c092a12-ed60-42c8-86b4-0427db78a5d3___RS_HL 0076.JPG_7761e96d-38f3-4b01-b520-8784552c0484.JPG
#   inflating: /content/drive/MyDrive/Tomato Dataset_KD_T5_A0.3_test2/tomato/val/Tomato___healthy/Tomato___healthy_original_1cb9d4d1-280b-479c-95a9-01f71acf70bc___RS_HL 0641.JPG_3cbbca6c-2ab7-429d-854f-1820a3642c6c.JPG
#   inflating: /content/drive/MyDrive/Tomato Dataset_KD_T5_A0.3_test2/tomato/val/Tomato___healthy/Tomato___healthy_original_1cb9d4d1-280b-479c-95a9-01f71acf70bc___RS_HL 0641.JPG_6ebf794b-0487-4cb4-bf92-d0990e806215.JPG
#   inflating: /content/drive/MyDrive/Tomato Dataset_KD_T5_A0.3_test2/tomato/val/Tomato___healthy/Tomato___healthy_original_1ddf5950-e27f-4928-8f4e-33242953e306___RS_HL 0181.JPG_a22a8359-6a7f-4de3-b97e-635ebf191803.JPG
#   inflating: /content/drive/MyDrive/Tomato Dataset_KD_T5_A0.3_test2/tomato/val/Tomato___healthy/Tomato___healthy_original_1dffd343-4634-4b33-95f4-eecc755aec8f___GH_HL Leaf 168.JPG_ae393258-6143-469a-870e-db2d63df5434.JPG

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, regularizers, callbacks, metrics
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.models import load_model, Model
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
TEACHER_MODEL_PATH  = "/content/drive/MyDrive/Model/EfficientNetB5_Test2.keras"
TRAIN_DIR           = "/content/drive/MyDrive/Tomato Dataset_KD_T5_A0.3_test2/tomato/train"
VALIDATION_DIR      = "/content/drive/MyDrive/Tomato Dataset_KD_T5_A0.3_test2/tomato/val"

# %%
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
NUM_CLASSES = 10
EPOCHS_KD = 30
TEMPERATURE = 5
ALPHA = 0.3

# %%
train_dataset = tf.keras.utils.image_dataset_from_directory(
    directory=TRAIN_DIR,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="categorical",
    color_mode="rgb",
    validation_split=0.1765,
    subset="training",
    seed=0
)

validation_dataset = tf.keras.utils.image_dataset_from_directory(
    directory=TRAIN_DIR,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="categorical",
    color_mode="rgb",
    validation_split=0.1765,
    subset="validation",
    seed=0
)

test_dataset = tf.keras.utils.image_dataset_from_directory(
    directory=VALIDATION_DIR,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="categorical",
    color_mode="rgb",
    shuffle=False
)

train_dataset = train_dataset.prefetch(tf.data.AUTOTUNE)
validation_dataset = validation_dataset.prefetch(tf.data.AUTOTUNE)
test_dataset = test_dataset.prefetch(tf.data.AUTOTUNE)
# Out:
# Found 10000 files belonging to 10 classes.
# Using 8235 files for training.
# Found 10000 files belonging to 10 classes.
# Using 1765 files for validation.
# Found 1000 files belonging to 10 classes.

# %%
data_augmentation = models.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.25),
    layers.RandomBrightness(0.3),
], name="ekstrem_augmentation")

# %%
def create_student_model(input_shape, num_classes):
    base_model = EfficientNetB0(
        weights='imagenet',
        include_top=False,
        input_shape=input_shape
    )
    base_model.trainable = False
    inputs = layers.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = base_model(x, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.4)(x)
    x = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001))(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation=None, name="student_logits")(x)
    model = models.Model(inputs, outputs, name="student_model")
    return model

# %%
print("Memuat Teacher Model...")
teacher_model = load_model(TEACHER_MODEL_PATH, compile=False)
teacher_model.trainable = False
print("Teacher Model Loaded.")
# Out:
# Memuat Teacher Model...
# Teacher Model Loaded.

# %%
class Distiller(keras.Model):
    def __init__(self, student, teacher):
        super().__init__()
        self.teacher = teacher
        self.student = student

        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.dist_loss_tracker = keras.metrics.Mean(name="dist_loss")
        self.student_loss_tracker = keras.metrics.Mean(name="student_loss")

        self.accuracy_metric = keras.metrics.CategoricalAccuracy(name="accuracy")
        self.auc_metric = keras.metrics.AUC(name="auc")
        self.precision_metric = keras.metrics.Precision(name="precision")
        self.recall_metric = keras.metrics.Recall(name="recall")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.dist_loss_tracker,
            self.student_loss_tracker,
            self.accuracy_metric,
            self.auc_metric,
            self.precision_metric,
            self.recall_metric
        ]

    def compile(self, optimizer, student_loss_fn, distillation_loss_fn, alpha=0.1, temperature=3):
        super().compile(optimizer=optimizer)
        self.student_loss_fn = student_loss_fn
        self.distillation_loss_fn = distillation_loss_fn
        self.alpha = alpha
        self.temperature = temperature

    def train_step(self, data):
        x, y = data
        x_teacher = tf.image.resize(x, [456, 456])
        teacher_predictions = self.teacher(x_teacher, training=False)

        with tf.GradientTape() as tape:
            student_logits = self.student(x, training=True)
            student_loss = self.student_loss_fn(y, student_logits)
            student_probs_temp = tf.nn.softmax(student_logits / self.temperature, axis=1)
            eps = 1e-7
            teacher_probs_safe = tf.clip_by_value(teacher_predictions, eps, 1.0 - eps)
            teacher_pseudo_logits = tf.math.log(teacher_probs_safe)
            teacher_probs_temp = tf.nn.softmax(teacher_pseudo_logits / self.temperature, axis=1)
            distillation_loss = self.distillation_loss_fn(teacher_probs_temp, student_probs_temp)
            distillation_loss = distillation_loss * (self.temperature ** 2)
            total_loss = (self.alpha * distillation_loss) + ((1 - self.alpha) * student_loss)
        gradients = tape.gradient(total_loss, self.student.trainable_variables)
        self.optimizer.apply_gradients(zip(gradients, self.student.trainable_variables))
        self.total_loss_tracker.update_state(total_loss)
        self.dist_loss_tracker.update_state(distillation_loss)
        self.student_loss_tracker.update_state(student_loss)
        student_probs = tf.nn.softmax(student_logits)
        self.accuracy_metric.update_state(y, student_probs)
        self.auc_metric.update_state(y, student_probs)
        self.precision_metric.update_state(y, student_probs)
        self.recall_metric.update_state(y, student_probs)

        return {m.name: m.result() for m in self.metrics}

    def test_step(self, data):
        x, y = data

        x_teacher = tf.image.resize(x, [456, 456])
        teacher_predictions = self.teacher(x_teacher, training=False)

        student_logits = self.student(x, training=False)
        student_loss = self.student_loss_fn(y, student_logits)
        eps = 1e-7
        teacher_probs_safe = tf.clip_by_value(teacher_predictions, eps, 1.0 - eps)
        teacher_pseudo_logits = tf.math.log(teacher_probs_safe)

        teacher_probs_temp = tf.nn.softmax(teacher_pseudo_logits / self.temperature, axis=1)
        student_probs_temp = tf.nn.softmax(student_logits / self.temperature, axis=1)

        distillation_loss = self.distillation_loss_fn(teacher_probs_temp, student_probs_temp)
        distillation_loss = distillation_loss * (self.temperature ** 2)
        total_loss = (self.alpha * distillation_loss) + ((1 - self.alpha) * student_loss)

        self.total_loss_tracker.update_state(total_loss)
        self.dist_loss_tracker.update_state(distillation_loss)
        self.student_loss_tracker.update_state(student_loss)

        student_probs = tf.nn.softmax(student_logits)
        self.accuracy_metric.update_state(y, student_probs)
        self.auc_metric.update_state(y, student_probs)
        self.precision_metric.update_state(y, student_probs)
        self.recall_metric.update_state(y, student_probs)

        return {m.name: m.result() for m in self.metrics}

# %%
import time
from datetime import timedelta
import tensorflow as tf
import keras

# Callback custom untuk menghitung waktu epoch (SAMA PERSIS)
class TimeTrackingCallback(tf.keras.callbacks.Callback):
    def __init__(self):
        self.epoch_times = []
        self.start_time = None

    def on_epoch_begin(self, epoch, logs=None):
        self.start_time = time.time()

    def on_epoch_end(self, epoch, logs=None):
        epoch_time = time.time() - self.start_time
        self.epoch_times.append(epoch_time)
        print(f"\nEpoch {epoch+1} selesai dalam {epoch_time:.2f} detik")

# Buat callback waktu KD
time_callback_kd = TimeTrackingCallback()

student_model = create_student_model((*IMAGE_SIZE, 3), NUM_CLASSES)
distiller = Distiller(student=student_model, teacher=teacher_model)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_total_loss",
    patience=8,
    restore_best_weights=True,
    mode="min"
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_total_loss",
    factor=0.2,
    patience=5,
    min_lr=1e-6,
    verbose=1,
    mode="min"
)

distiller.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    student_loss_fn=keras.losses.CategoricalCrossentropy(from_logits=True),
    distillation_loss_fn=keras.losses.KLDivergence(),
    alpha=ALPHA,
    temperature=TEMPERATURE
)

print("\nMemulai Pelatihan Model Murid (Knowledge Distillation)...")

# Training dengan callback waktu
history = distiller.fit(
    train_dataset,
    epochs=EPOCHS_KD,
    validation_data=validation_dataset,
    callbacks=[early_stopping, reduce_lr, time_callback_kd]  # ✅ Tambah time_callback_kd
)

# Hitung dan tampilkan statistik waktu (SAMA PERSIS)
if len(time_callback_kd.epoch_times) > 0:
    avg_epoch_time = sum(time_callback_kd.epoch_times) / len(time_callback_kd.epoch_times)
    total_time = sum(time_callback_kd.epoch_times)

    print("\n" + "="*50)
    print("HASIL WAKTU PELATIHAN KD")
    print("="*50)
    print(f"Total epoch yang dijalankan: {len(time_callback_kd.epoch_times)}")
    print(f"Waktu rata-rata per epoch:  {avg_epoch_time:.2f} detik ({avg_epoch_time/60:.2f} menit)")
    print(f"Total waktu pelatihan:      {total_time:.2f} detik ({total_time/60:.2f} menit)")
    print(f"Waktu tercepat:            {min(time_callback_kd.epoch_times):.2f} detik")
    print(f"Waktu terlama:             {max(time_callback_kd.epoch_times):.2f} detik")
    print("="*50)
else:
    print("\nTidak ada data waktu epoch yang tersedia.")
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# Memulai Pelatihan Model Murid (Knowledge Distillation)...
# Epoch 1/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5124 - auc: 0.8583 - dist_loss: 7.0996 - precision: 0.5860 - recall: 0.4442 - student_loss: 1.6728 - total_loss: 3.3009
# Epoch 1 selesai dalam 387.34 detik
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 387s 1s/step - accuracy: 0.6346 - auc: 0.9292 - dist_loss: 5.1906 - precision: 0.7024 - recall: 0.5837 - student_loss: 1.1668 - total_loss: 2.3739 - val_accuracy: 0.8091 - val_auc: 0.9803 - val_dist_loss: 3.3814 - val_precision: 0.8896 - val_recall: 0.7484 - val_student_loss: 0.5799 - val_total_loss: 1.4204 - learning_rate: 0.0010
# Epoch 2/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7656 - auc: 0.9700 - dist_loss: 3.6622 - precision: 0.8069 - recall: 0.7312 - student_loss: 0.7071 - total_loss: 1.5936
# Epoch 2 selesai dalam 344.25 detik
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 344s 1s/step - accuracy: 0.7685 - auc: 0.9713 - dist_loss: 3.5225 - precision: 0.8094 - recall: 0.7331 - student_loss: 0.6905 - total_loss: 1.5401 - val_accuracy: 0.8368 - val_auc: 0.9835 - val_dist_loss: 2.0422 - val_precision: 0.8840 - val_recall: 0.8113 - val_student_loss: 0.4912 - val_total_loss: 0.9565 - learning_rate: 0.0010
# Epoch 3/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7982 - auc: 0.9753 - dist_loss: 3.2598 - precision: 0.8345 - recall: 0.7628 - student_loss: 0.6219 - total_loss: 1.4133
# Epoch 3 selesai dalam 343.66 detik
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 344s 1s/step - accuracy: 0.8017 - auc: 0.9762 - dist_loss: 3.2059 - precision: 0.8410 - recall: 0.7662 - student_loss: 0.6088 - total_loss: 1.3879 - val_accuracy: 0.8669 - val_auc: 0.9880 - val_dist_loss: 1.7287 - val_precision: 0.8996 - val_recall: 0.8425 - val_student_loss: 0.4080 - val_total_loss: 0.8042 - learning_rate: 0.0010
# Epoch 4/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8050 - auc: 0.9803 - dist_loss: 3.0567 - precision: 0.8429 - recall: 0.7719 - student_loss: 0.5687 - total_loss: 1.3151
# Epoch 4 selesai dalam 343.05 detik
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 343s 1s/step - accuracy: 0.8084 - auc: 0.9807 - dist_loss: 2.9982 - precision: 0.8493 - recall: 0.7762 - student_loss: 0.5556 - total_loss: 1.2884 - val_accuracy: 0.8538 - val_auc: 0.9862 - val_dist_loss: 1.9019 - val_precision: 0.8885 - val_recall: 0.8351 - val_student_loss: 0.4322 - val_total_loss: 0.8731 - learning_rate: 0.0010
# Epoch 5/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8146 - auc: 0.9806 - dist_loss: 2.9824 - precision: 0.8561 - recall: 0.7777 - student_loss: 0.5416 - total_loss: 1.2738
# Epoch 5 selesai dalam 343.63 detik
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 344s 1s/step - accuracy: 0.8204 - auc: 0.9817 - dist_loss: 2.9261 - precision: 0.8597 - recall: 0.7825 - student_loss: 0.5280 - total_loss: 1.2474 - val_accuracy: 0.8663 - val_auc: 0.9890 - val_dist_loss: 1.7264 - val_precision: 0.8984 - val_recall: 0.8465 - val_student_loss: 0.4081 - val_total_loss: 0.8036 - learning_rate: 0.0010
# Epoch 6/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8181 - auc: 0.9836 - dist_loss: 2.8698 - precision: 0.8589 - recall: 0.7848 - student_loss: 0.5118 - total_loss: 1.2192
# Epoch 6 selesai dalam 382.28 detik
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 382s 1s/step - accuracy: 0.8209 - auc: 0.9832 - dist_loss: 2.8478 - precision: 0.8611 - recall: 0.7846 - student_loss: 0.5113 - total_loss: 1.2122 - val_accuracy: 0.8669 - val_auc: 0.9893 - val_dist_loss: 1.7066 - val_precision: 0.8944 - val_recall: 0.8448 - val_student_loss: 0.4075 - val_total_loss: 0.7972 - learning_rate: 0.0010
# Epoch 7/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8308 - auc: 0.9839 - dist_loss: 2.7924 - precision: 0.8664 - recall: 0.7923 - student_loss: 0.4944 - total_loss: 1.1838
# Epoch 7 selesai dalam 343.70 detik
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 344s 1s/step - accuracy: 0.8300 - auc: 0.9837 - dist_loss: 2.7945 - precision: 0.8676 - recall: 0.7894 - student_loss: 0.5001 - total_loss: 1.1884 - val_accuracy: 0.8748 - val_auc: 0.9903 - val_dist_loss: 1.6107 - val_precision: 0.9065 - val_recall: 0.8516 - val_student_loss: 0.3828 - val_total_loss: 0.7511 - learning_rate: 0.0010
# Epoch 8/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.
detik
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 344s 1s/step - accuracy: 0.8463 - auc: 0.9870 - dist_loss: 2.5810 - precision: 0.8794 - recall: 0.8137 - student_loss: 0.4496 - total_loss: 1.0890 - val_accuracy: 0.8867 - val_auc: 0.9915 - val_dist_loss: 1.5386 - val_precision: 0.9186 - val_recall: 0.8691 - val_student_loss: 0.3540 - val_total_loss: 0.7094 - learning_rate: 0.0010
# Epoch 14/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8601 - auc: 0.9876 - dist_loss: 2.6092 - precision: 0.8883 - recall: 0.8216 - student_loss: 0.4266 - total_loss: 1.0813
# Epoch 14 selesai dalam 343.47 detik
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 343s 1s/step - accuracy: 0.8556 - auc: 0.9879 - dist_loss: 2.5934 - precision: 0.8858 - recall: 0.8222 - student_loss: 0.4244 - total_loss: 1.0751 - val_accuracy: 0.8907 - val_auc: 0.9922 - val_dist_loss: 1.4920 - val_precision: 0.9175 - val_recall: 0.8691 - val_student_loss: 0.3362 - val_total_loss: 0.6830 - learning_rate: 0.0010
# Epoch 15/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8561 - auc: 0.9887 - dist_loss: 2.5672 - precision: 0.8942 - recall: 0.8202 - student_loss: 0.4168 - total_loss: 1.0619
# Epoch 15 selesai dalam 343.52 detik
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 344s 1s/step - accuracy: 0.8538 - auc: 0.9883 - dist_loss: 2.5706 - precision: 0.8882 - recall: 0.8187 - student_loss: 0.4265 - total_loss: 1.0697 - val_accuracy: 0.8873 - val_auc: 0.9926 - val_dist_loss: 1.5097 - val_precision: 0.9207 - val_recall: 0.8680 - val_student_loss: 0.3276 - val_total_loss: 0.6822 - learning_rate: 0.0010
# Epoch 16/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8532 - auc: 0.9883 - dist_loss: 2.5902 - precision: 0.8837 - recall: 0.8202 - student_loss: 0.4275 - total_loss: 1.0763
# Epoch 16 selesai dalam 343.09 detik
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 343s 1s/step - accuracy: 0.8536 - auc: 0.9885 - dist_loss: 2.5793 - precision: 0.8862 - recall: 0.8196 - student_loss: 0.4244 - total_loss: 1.0709 - val_accuracy: 0.8680 - val_auc: 0.9904 - val_dist_loss: 1.6675 - val_precision: 0.8977 - val_recall: 0.8448 - val_student_loss: 0.3853 - val_total_loss: 0.7699 - learning_rate: 0.0010
# Epoch 17/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8585 - auc: 0.9892 - dist_loss: 2.5208 - precision: 0.8909 - recall: 0.8207 - student_loss: 0.4115 - total_loss: 1.0443
# Epoch 17 selesai dalam 343.56 detik
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 344s 1s/step - accuracy: 0.8588 - auc: 0.9895 - dist_loss: 2.5268 - precision: 0.8908 - recall: 0.8223 - student_loss: 0.4057 - total_loss: 1.0420 - val_accuracy: 0.8833 - val_auc: 0.9920 - val_dist_loss: 1.5908 - val_precision: 0.9158 - val_recall: 0.8629 - val_student_loss: 0.3484 - val_total_loss: 0.7211 - learning_rate: 0.0010
# Epoch 18/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8609 - auc: 0.9896 - dist_loss: 2.5219 - precision: 0.8910 - recall: 0.8245 - student_loss: 0.3969 - total_loss: 1.0344
# Epoch 18 selesai dalam 342.88 detik
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 343s 1s/step - accuracy: 0.8572 - auc: 0.9891 - dist_loss: 2.5383 - precision: 0.8882 - recall: 0.8237 - student_loss: 0.4100 - total_loss: 1.0485 - val_accuracy: 0.8822 - val_auc: 0.9919 - val_dist_loss: 1.5930 - val_precision: 0.9119 - val_recall: 0.8623 - val_student_loss: 0.3614 - val_total_loss: 0.7309 - learning_rate: 0.0010
# Epoch 19/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8509 - auc: 0.9882 - dist_loss: 2.5755 - precision: 0.8836 - recall: 0.8197 - student_loss: 0.4269 - total_loss: 1.0715
# Epoch 19 selesai dalam 343.13 detik
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 343s 1s/step - accuracy: 0.8529 - auc: 0.9881 - dist_loss: 2.5642 - precision: 0.8855 - recall: 0.8205 - student_loss: 0.4242 - total_loss: 1.0662 - val_accuracy: 0.8754 - val_auc: 0.9912 - val_dist_loss: 1.6408 - val_precision: 0.9029 - val_recall: 0.8584 - val_student_loss: 0.3592 - val_total_loss: 0.7437 - learning_rate: 0.0010
# Epoch 20/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8587 - auc: 0.9888 - dist_loss: 2.5406 - precision: 0.8908 - recall: 0.8266 - student_loss: 0.4146 - total_loss: 1.0524
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 20 selesai dalam 343.41 detik
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 343s 1s/step - accuracy: 0.8608 - auc: 0.9887 - dist_loss: 2.5308 - precision: 0.8913 - recall: 0.8283 - student_loss: 0.4120 - total_loss: 1.0477 - val_accuracy: 0.8822 - val_auc: 0.9908 - val_dist_loss: 1.5628 - val_precision: 0.9075 - val_recall: 0.8612 - val_student_loss: 0.3618 - val_total_loss: 0.7221 - learning_rate: 0.0010
# Epoch 21/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8663 - auc: 0.9882 - dist_loss: 2.5105 - precision: 0.8944 - recall: 0.8347 - student_loss: 0.4106 - total_loss: 1.0406
# Epoch 21 selesai dalam 343.83 detik
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 344s 1s/step - accuracy: 0.8623 - auc: 0.9889 - dist_loss: 2.4778 - precision: 0.8943 - recall: 0.8329 - student_loss: 0.4053 - total_loss: 1.0270 - val_accuracy: 0.8901 - val_auc: 0.9926 - val_dist_loss: 1.4385 - val_precision: 0.9211 - val_recall: 0.8663 - val_student_loss: 0.3246 - val_total_loss: 0.6588 - learning_rate: 2.0000e-04
# Epoch 22/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8714 - auc: 0.9906 - dist_loss: 2.4551 - precision: 0.9027 - recall: 0.8370 - student_loss: 0.3847 - total_loss: 1.0058
# Epoch 22 selesai dalam 343.17 detik
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 343s 1s/step - accuracy: 0.8670 - auc: 0.9899 - dist_loss: 2.4457 - precision: 0.9005 - recall: 0.8329 - student_loss: 0.3969 - total_loss: 1.0115 - val_accuracy: 0.8912 - val_auc: 0.9930 - val_dist_loss: 1.4355 - val_precision: 0.9212 - val_recall: 0.8674 - val_student_loss: 0.3342 - val_total_loss: 0.6646 - learning_rate: 2.0000e-04
# Epoch 23/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8674 - auc: 0.9907 - dist_loss: 2.4197 - precision: 0.9010 - recall: 0.8354 - student_loss: 0.3815 - total_loss: 0.9929
# Epoch 23 selesai dalam 343.31 detik
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 343s 1s/step - accuracy: 0.8653 - auc: 0.9904 - dist_loss: 2.4150 - precision: 0.8997 - recall: 0.8341 - student_loss: 0.3886 - total_loss: 0.9966 - val_accuracy: 0.8912 - val_auc: 0.9927 - val_dist_loss: 1.4230 - val_precision: 0.9230 - val_recall: 0.8697 - val_student_loss: 0.3229 - val_total_loss: 0.6529 - learning_rate: 2.0000e-04
# Epoch 24/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8760 - auc: 0.9904 - dist_loss: 2.3867 - precision: 0.9053 - recall: 0.8435 - student_loss: 0.3745 - total_loss: 0.9781
# Epoch 24 selesai dalam 343.55 detik
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 344s 1s/step - accuracy: 0.8747 - auc: 0.9906 - dist_loss: 2.3709 - precision: 0.9060 - recall: 0.8430 - student_loss: 0.3719 - total_loss: 0.9716 - val_accuracy: 0.8912 - val_auc: 0.9929 - val_dist_loss: 1.4056 - val_precision: 0.9203 - val_recall: 0.8703 - val_student_loss: 0.3168 - val_total_loss: 0.6434 - learning_rate: 2.0000e-04
# Epoch 25/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8660 - auc: 0.9905 - dist_loss: 2.4086 - precision: 0.9015 - recall: 0.8365 - student_loss: 0.3799 - total_loss: 0.9885
# Epoch 25 selesai dalam 343.33 detik
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 343s 1s/step - accuracy: 0.8684 - auc: 0.9901 - dist_loss: 2.4041 - precision: 0.8984 - recall: 0.8378 - student_loss: 0.3843 - total_loss: 0.9902 - val_accuracy: 0.8912 - val_auc: 0.9931 - val_dist_loss: 1.4373 - val_precision: 0.9186 - val_recall: 0.8697 - val_student_loss: 0.3152 - val_total_loss: 0.6519 - learning_rate: 2.0000e-04
# Epoch 26/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8743 - auc: 0.9902 - dist_loss: 2.3942 - precision: 0.9071 - recall: 0.8421 - student_loss: 0.3750 - total_loss: 0.9808
# Epoch 26 selesai dalam 343.35 detik
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 343s 1s/step - accuracy: 0.8701 - auc: 0.9899 - dist_loss: 2.4187 - precision: 0.9027 - recall: 0.8390 - student_loss: 0.3876 - total_loss: 0.9969 - val_accuracy: 0.8958 - val_auc: 0.9934 - val_dist_loss: 1.4310 - val_precision: 0.9273 - val_recall: 0.8742 - val_student_loss: 0.3130 - val_total_loss: 0.6484 - learning_rate: 2.0000e-04
# Epoch 27/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8677 - auc: 0.9906 - dist_loss: 2.3641 - precision: 0.8965 - recall: 0.8374 - student_loss: 0.3801 - total_loss: 0.9753
# Epoch 27 selesai dalam 342.91 detik
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 343s 1s/step - accuracy: 0.8693 - auc: 0.9907 - dist_loss: 2.3674 - precision: 0.8979 - recall: 0.8397 - student_loss: 0.3765 - total_loss: 0.9738 - val_accuracy: 0.8958 - val_auc: 0.9935 - val_dist_loss: 1.4231 - val_precision: 0.9272 - val_recall: 0.8725 - val_student_loss: 0.3134 - val_total_loss: 0.6463 - learning_rate: 2.0000e-04
# Epoch 28/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8696 - auc: 0.9899 - dist_loss: 2.4272 - precision: 0.8992 - recall: 0.8361 - student_loss: 0.3928 - total_loss: 1.0031
# Epoch 28 selesai dalam 342.54 detik
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 343s 1s/step - accuracy: 0.8708 - auc: 0.9901 - dist_loss: 2.4120 - precision: 0.8985 - recall: 0.8375 - student_loss: 0.3915 - total_loss: 0.9977 - val_accuracy: 0.8958 - val_auc: 0.9939 - val_dist_loss: 1.4058 - val_precision: 0.9279 - val_recall: 0.8754 - val_student_loss: 0.3169 - val_total_loss: 0.6436 - learning_rate: 2.0000e-04
# Epoch 29/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8673 - auc: 0.9906 - dist_loss: 2.3767 - precision: 0.8994 - recall: 0.8395 - student_loss: 0.3764 - total_loss: 0.9765
# Epoch 29 selesai dalam 343.33 detik
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 343s 1s/step - accuracy: 0.8715 - auc: 0.9905 - dist_loss: 2.3667 - precision: 0.9030 - recall: 0.8424 - student_loss: 0.3771 - total_loss: 0.9740 - val_accuracy: 0.8952 - val_auc: 0.9933 - val_dist_loss: 1.3922 - val_precision: 0.9253 - val_recall: 0.8771 - val_student_loss: 0.3108 - val_total_loss: 0.6353 - learning_rate: 2.0000e-04
# Epoch 30/30
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8740 - auc: 0.9907 - dist_loss: 2.3714 - precision: 0.9031 - recall: 0.8421 - student_loss: 0.3722 - total_loss: 0.9720
# Epoch 30 selesai dalam 343.23 detik
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 343s 1s/step - accuracy: 0.8766 - auc: 0.9913 - dist_loss: 2.3607 - precision: 0.9060 - recall: 0.8446 - student_loss: 0.3663 - total_loss: 0.9646 - val_accuracy: 0.8958 - val_auc: 0.9931 - val_dist_loss: 1.4321 - val_precision: 0.9221 - val_recall: 0.8720 - val_student_loss: 0.3160 - val_total_loss: 0.6508 - learning_rate: 2.0000e-04
#
# ==================================================
# HASIL WAKTU PELATIHAN KD
# ==================================================
# Total epoch yang dijalankan: 30
# Waktu rata-rata per epoch:  346.18 detik (5.77 menit)
# Total waktu pelatihan:      10385.51 detik (173.09 menit)
# Waktu tercepat:            342.54 detik
# Waktu terlama:             387.34 detik
# ==================================================

# %%
import matplotlib.pyplot as plt

# Fungsi visualisasi SAMA PERSIS dengan teacher (6 subplot)
def plot_kd_metrics_complete(history):
    plt.figure(figsize=(18, 10))
    plt.suptitle('Training and Validation Metrics - Student Model (KD)', fontsize=16)

    # 1. Plot Loss (total_loss untuk KD)
    plt.subplot(2, 3, 1)
    plt.plot(history.history['total_loss'], label='Train Loss', linewidth=2)
    plt.plot(history.history['val_total_loss'], label='Val Loss', linewidth=2, linestyle='--')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.title('Total Loss')

    # 2. Plot Accuracy
    plt.subplot(2, 3, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
    plt.plot(history.history['val_accuracy'], label='Val Accuracy', linewidth=2, linestyle='--')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.title('Accuracy')

    # 3. Plot AUC
    plt.subplot(2, 3, 3)
    plt.plot(history.history['auc'], label='Train AUC', linewidth=2)
    plt.plot(history.history['val_auc'], label='Val AUC', linewidth=2, linestyle='--')
    plt.xlabel('Epoch')
    plt.ylabel('AUC')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.title('AUC')

    # 4. Plot Precision
    plt.subplot(2, 3, 4)
    plt.plot(history.history['precision'], label='Train Precision', linewidth=2)
    plt.plot(history.history['val_precision'], label='Val Precision', linewidth=2, linestyle='--')
    plt.xlabel('Epoch')
    plt.ylabel('Precision')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.title('Precision')

    # 5. Plot Recall
    plt.subplot(2, 3, 5)
    plt.plot(history.history['recall'], label='Train Recall', linewidth=2)
    plt.plot(history.history['val_recall'], label='Val Recall', linewidth=2, linestyle='--')
    plt.xlabel('Epoch')
    plt.ylabel('Recall')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.title('Recall')

    # 6. Plot Distillation Loss (BONUS - unik untuk KD)
    plt.subplot(2, 3, 6)
    plt.plot(history.history['dist_loss'], label='Train Distillation Loss', linewidth=2)
    if 'val_dist_loss' in history.history:
        plt.plot(history.history['val_dist_loss'], label='Val Distillation Loss', linewidth=2, linestyle='--')
    plt.xlabel('Epoch')
    plt.ylabel('Distillation Loss')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.title('Distillation Loss')

    plt.tight_layout()
    plt.show()

# 🎨 Panggil visualisasi KD (SAMA PERSIS layout)
plot_kd_metrics_complete(history)

# 📊 Evaluasi Test Set (tetap sama)
print("\n=== 📊 Evaluasi Test Set (Student KD) ===")
test_results = distiller.evaluate(test_dataset)
print("Test Results:", dict(zip(distiller.metrics_names, test_results)))
# Out:
# === 📊 Evaluasi Test Set (Student KD) ===
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.9030 - auc: 0.9935 - dist_loss: 1.5063 - precision: 0.9229 - recall: 0.8860 - student_loss: 0.3015 - total_loss: 0.6630
# Test Results: {'total_loss': 0.6629726886749268, 'dist_loss': 1.5063215494155884, 'student_loss': 0.30153754353523254, 'accuracy': 0.902999997138977, 'auc': 0.9934887290000916, 'precision': 0.9229166507720947, 'recall': 0.8859999775886536}

# %%
print("\n--- Menyimpan Model ---")
save_path = "/content/drive/MyDrive/Model/EfficientNetB0_KD_T5_A0.3.keras"
student_model.save(save_path)
print(f"Model berhasil disimpan di: {save_path}")
# Out:
# --- Menyimpan Model ---
# Model berhasil disimpan di: /content/drive/MyDrive/Model/EfficientNetB0_KD_T5_A0.3.keras

# %%
print("\n" + "="*50)
print("🔍 STUDENT MODEL (KD) PERFORMANCE ANALYSIS")
print("="*50)

# 1. Model Size (SAMA PERSIS)
size_mb = os.path.getsize(save_path)/(1024*1024)
print(f"📦 Model Size     : {size_mb:.2f} MB")

# Input shape SAMA dengan teacher
input_shape = (1, IMAGE_SIZE[0], IMAGE_SIZE[1], 3)  # Gunakan IMAGE_SIZE teacher
dummy = tf.random.normal(input_shape)

print(f"\n⏱️  Testing Inference Speed (IMAGE_SIZE={IMAGE_SIZE})...")

# WARM-UP (SAMA PERSIS)
print("  Warming up...")
for _ in range(10):
    _ = student_model(dummy, training=False)

# Test 100 gambar untuk rata-rata akurat (SAMA PERSIS)
n_test = 100
latencies = []

print(f"  Testing {n_test} images Student Model (KD)...")
start_total = time.time()

for i in range(n_test):
    start = time.time()
    _ = student_model(dummy, training=False)
    latency = (time.time() - start) * 1000  # ms
    latencies.append(latency)

end_total = time.time()

# Results (SAMA PERSIS format)
avg_latency = np.mean(latencies[10:])  # Skip first 10
min_latency = np.min(latencies[10:])
max_latency = np.max(latencies[10:])
throughput = 1000 / avg_latency

print(f"\n📈 INFERENCE RESULTS Student Model (KD):")
print(f"  Average Latency : {avg_latency:.2f} ms **PER IMAGE**")
print(f"  Min Latency     : {min_latency:.2f} ms")
print(f"  Max Latency     : {max_latency:.2f} ms")
print(f"  Throughput      : {throughput:.1f} images/second")
print(f"  Total {n_test} imgs: {(end_total-start_total)*1000:.2f} ms")

print("\n" + "="*50)
# Out:
# ==================================================
# 🔍 STUDENT MODEL (KD) PERFORMANCE ANALYSIS
# ==================================================
# 📦 Model Size     : 16.93 MB
#
# ⏱️  Testing Inference Speed (IMAGE_SIZE=(224, 224))...
#   Warming up...
#   Testing 100 images Student Model (KD)...
#
# 📈 INFERENCE RESULTS Student Model (KD):
#   Average Latency : 296.25 ms **PER IMAGE**
#   Min Latency     : 256.33 ms
#   Max Latency     : 429.90 ms
#   Throughput      : 3.4 images/second
#   Total 100 imgs: 30444.65 ms
#
# ==================================================
